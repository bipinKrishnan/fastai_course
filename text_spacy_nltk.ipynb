# %% [markdown]
# <a href="https://colab.research.google.com/github/bipinKrishnan/fastai_course/blob/master/text_spacy_nltk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')

# %%
text = "Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation."

# %%
tokens = nltk.word_tokenize(text)

nltk.pos_tag(tokens), nltk.pos_tag(tokens)
# Out:
# ([('Wikipedia', 'NNP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('free', 'JJ'),
#   ('online', 'NN'),
#   ('encyclopedia', 'NN'),
#   (',', ','),
#   ('created', 'VBN'),
#   ('and', 'CC'),
#   ('edited', 'VBN'),
#   ('by', 'IN'),
#   ('volunteers', 'NNS'),
#   ('around', 'IN'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('and', 'CC'),
#   ('hosted', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('Wikimedia', 'NNP'),
#   ('Foundation', 'NNP'),
#   ('.', '.')],
#  [('Wikipedia', 'NNP'),
#   ('is', 'VBZ'),
#   ('a', 'DT'),
#   ('free', 'JJ'),
#   ('online', 'NN'),
#   ('encyclopedia', 'NN'),
#   (',', ','),
#   ('created', 'VBN'),
#   ('and', 'CC'),
#   ('edited', 'VBN'),
#   ('by', 'IN'),
#   ('volunteers', 'NNS'),
#   ('around', 'IN'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('and', 'CC'),
#   ('hosted', 'VBN'),
#   ('by', 'IN'),
#   ('the', 'DT'),
#   ('Wikimedia', 'NNP'),
#   ('Foundation', 'NNP'),
#   ('.', '.')])

# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
text1 = nlp("Wikipedia is a free online encyclopedia, created and edited by volunteers around the world and hosted by the Wikimedia Foundation.")

# %%
#parts of speech, tagging and lemmatizing using spacy
[(word.text, word.pos_, word.tag_, word.lemma_) for word in text1]
# Out:
# [('Wikipedia', 'PROPN', 'NNP', 'Wikipedia'),
#  ('is', 'AUX', 'VBZ', 'be'),
#  ('a', 'DET', 'DT', 'a'),
#  ('free', 'ADJ', 'JJ', 'free'),
#  ('online', 'NOUN', 'NN', 'online'),
#  ('encyclopedia', 'NOUN', 'NN', 'encyclopedia'),
#  (',', 'PUNCT', ',', ','),
#  ('created', 'VERB', 'VBN', 'create'),
#  ('and', 'CCONJ', 'CC', 'and'),
#  ('edited', 'VERB', 'VBN', 'edit'),
#  ('by', 'ADP', 'IN', 'by'),
#  ('volunteers', 'NOUN', 'NNS', 'volunteer'),
#  ('around', 'ADP', 'IN', 'around'),
#  ('the', 'DET', 'DT', 'the'),
#  ('world', 'NOUN', 'NN', 'world'),
#  ('and', 'CCONJ', 'CC', 'and'),
#  ('hosted', 'VERB', 'VBN', 'host'),
#  ('by', 'ADP', 'IN', 'by'),
#  ('the', 'DET', 'DT', 'the'),
#  ('Wikimedia', 'PROPN', 'NNP', 'Wikimedia'),
#  ('Foundation', 'PROPN', 'NNP', 'Foundation'),
#  ('.', 'PUNCT', '.', '.')]

# %%
spacy.explain('CCONJ')
# Out:
# 'coordinating conjunction'

# %%
displacy.render(text1, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9150de47f92148f1a773f993b8c1f894-0" class="displacy" width="3550" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Wikipedia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
# ...

# %% [markdown]
# Named Entity Recognition

# %%
nlp = spacy.load('en')

# %%
text2 = nlp("Facebook, Inc. (stylized as FACEBOOK) is an American social media conglomerate corporation based in Menlo Park, California. It was founded by Mark Zuckerberg, along with his fellow roommates and students at Harvard College, who were Eduardo Saverin, Andrew McCollum, Dustin Moskovitz and Chris Hughes, originally as TheFacebook.com—today's Facebook, a popular global social networking website. Facebook is one of the world's most valuable companies. It is considered one of the Big Five technology companies along with Microsoft, Amazon, Apple, and Google.")

# %%
[(word.text, word.label_) for word in text2.ents]
# Out:
# [('Facebook, Inc.', 'ORG'),
#  ('FACEBOOK', 'ORG'),
#  ('American', 'NORP'),
#  ('Menlo Park', 'GPE'),
#  ('California', 'GPE'),
#  ('Mark Zuckerberg', 'PERSON'),
#  ('Harvard College', 'ORG'),
#  ('Eduardo Saverin', 'PERSON'),
#  ('Andrew McCollum', 'PERSON'),
#  ('Dustin Moskovitz', 'PERSON'),
#  ('Chris Hughes', 'PERSON'),
#  ('TheFacebook.com', 'ORG'),
#  ('today', 'DATE'),
#  ('one', 'CARDINAL'),
#  ('one', 'CARDINAL'),
#  ('Five', 'CARDINAL'),
#  ('Microsoft', 'ORG'),
#  ('Amazon', 'ORG'),
#  ('Apple', 'ORG'),
#  ('Google', 'ORG')]

# %%
spacy.explain('CARDINAL')
# Out:
# 'Numerals that do not fall under another type'

# %%
displacy.render(text2, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3984cc28bc2646339c5af7cf33fa86f2-0" class="displacy" width="14575" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Facebook,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Inc. (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
# ...

# %%
displacy.render(text2, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook, Inc.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (stylized as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FACEBOOK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) is an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
# ...

# %%
[(ents.label_, spacy.explain(ents.label_)) for ents in text2.ents]
# Out:
# [('ORG', 'Companies, agencies, institutions, etc.'),
#  ('ORG', 'Companies, agencies, institutions, etc.'),
#  ('NORP', 'Nationalities or religious or political groups'),
#  ('GPE', 'Countries, cities, states'),
#  ('GPE', 'Countries, cities, states'),
#  ('PERSON', 'People, including fictional'),
#  ('ORG', 'Companies, agencies, institutions, etc.'),
#  ('PERSON', 'People, including fictional'),
#  ('PERSON', 'People, including fictional'),
#  ('PERSON', 'People, including fictional'),
#  ('PERSON', 'People, including fictional'),
#  ('ORG', 'Companies, agencies, institutions, etc.'),
#  ('DATE', 'Absolute or relative dates or periods'),
#  ('CARDINAL', 'Numerals that do not fall under another type'),
#  ('CARDINAL', 'Numerals that do not fall under another type'),
#  ('CARDINAL', 'Numerals that do not fall under another type'),
#  ('ORG', 'Companies, agencies, institutions, etc.'),
#  ('ORG', 'Companies, agencies, institutions, etc.'),
# ...

# %% [markdown]
# # Exercise

# %%
#@title Run this cell, put your text in the text area and click enter
import spacy
from spacy import displacy

text = input(str("Enter your text"))

nlp = spacy.load('en')
inp_text = nlp(text)

displacy.render(inp_text, style='ent', jupyter=True)
displacy.render(inp_text, jupyter=True)
# Out:
# Enter your textOpenAI is an artificial intelligence research laboratory consisting of the for-profit corporation OpenAI LP and its parent company, the non-profit OpenAI Inc. The company, considered a competitor to DeepMind, conducts research in the field of artificial intelligence (AI) with the stated goal of promoting and developing friendly AI in a way that benefits humanity as a whole. The organization was founded in San Francisco in late 2015 by Elon Musk, Sam Altman, and others, who collectively pledged US$1 billion. Musk resigned from the board in February 2018 but remained a donor. In 2019, OpenAI LP received a US$1 billion investment from Microsoft.
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">OpenAI is an artificial intelligence research laboratory consisting of the for-profit corporation OpenAI LP and its parent company, the non-profit OpenAI Inc. The company, considered a competitor to
# ...
